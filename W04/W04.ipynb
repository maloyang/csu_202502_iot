# %% [markdown]
# # Demo: 公共腳踏車應用 2

# %% [markdown]
# ## 新北市公共自行車租賃系統(YouBike): https://data.gov.tw/dataset/123026

# %%
import requests

# 原來的政府公開資訊
#url = "https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/csv/file"
url = 'https://raw.githubusercontent.com/maloyang/csu_202302_ML/main/W03/bike_02_%E6%96%B0%E5%8C%97%E5%B8%82.csv'
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
# 把資料用utf-8解碼，並利用csv的模組解析資料成為 list 格式

import csv

decoded_content = r.content.decode('utf-8')
#print(decoded_content)

cr = csv.reader(decoded_content.splitlines(), delimiter=',')
data_list = list(cr)

# %%
print(data_list[1])
# Out:
# ['1001', '大鵬華城', '20', '2', '新店區', '20221119114343', '24.99116', '121.53398', '新北市新店區中正路700巷3號', 'Xindian Dist.', 'Dapeng Community', 'No. 3, Lane 700 Chung Cheng Road, Xindian District', '17', '1']

# %% [markdown]
# - 使用folium地圖套件進行資料視覺化應用
# - 使用geopy取得GPS資料
#
# - 安裝方式:
# ```bash
# pip install folium
# pip install geopy
# ```

# %%
# 在colab用底下的安裝指令
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)

# %%
#引入相關套件，並建立取得GPS座標的function
import folium
import geopy
from geopy.geocoders import Nominatim

def get_gps_coordinates(location_name):
    """
    取得指定地名的 GPS 座標。

    Args:
        location_name (str): 地名。

    Returns:
        tuple: (緯度, 經度)，如果找不到則返回 None。
    """
    try:
        geolocator = Nominatim(user_agent="my_geocoder")
        location = geolocator.geocode(location_name)
        if location:
            return location.latitude, location.longitude
        else:
            return None
    except Exception as e:
        print(f"發生錯誤：{e}")
        return None

# %%
# 使用 geocoder 取得特定住址的 GPS 座標
location = get_gps_coordinates('新北市')
print(location)
# Out:
# (25.011997, 121.4656619)

# %%
# TODO: 試著用map呈現資料，並顯示剩餘車輛

# %%
m = folium.Map(location = location, zoom_start=15)
for item in data_list[1:]:
    try:
        my_gps = [float(item[6]), float(item[7])]
        n = int(item[3])
        msg = '[%s]剩 %s 台' %(item[1], n)
        folium.Marker(my_gps, tooltip=msg, icon=folium.Icon(color='green', prefix='fa', icon='fa-bicycle')).add_to(m)
    except Exception as e:
        print(e.args)

# %%
# TODO: 試著用map呈現資料，並顯示剩餘車輛，並把用顏色區分不同數量，3台以上為綠色，以下為紅色
# hint: folium.Marker([float(lat), float(lng)], popup='剩餘車輛:,',icon=folium.Icon(color='red', prefix='fa', icon='fa-bicycle')).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fcfad9fde18f58e66524c4949e10cf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fcfad9fde18f58e66524c4949e10cf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fcfad9fde18f58e66524c4949e10cf4 = L.map(
#                 &quot;map_0fcfad9fde18f58e66524c4949e10cf4&quot;,
#                 {
#                     center: [25.011997, 121.4656619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0309a720c0c0d22cd7e7f423b6df3eec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var marker_fbd64486559538e68383e25028e12bb0 = L.marker(
#                 [24.99116, 121.53398],
#                 {}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var icon_ac1e7246e5e59b9c0b195058aad12001 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fbd64486559538e68383e25028e12bb0.setIcon(icon_ac1e7246e5e59b9c0b195058aad12001);
#
#
#             marker_fbd64486559538e68383e25028e12bb0.bindTooltip(
#                 `&lt;div&gt;
#                      [大鵬華城]剩 2 台
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c8284d6722b2101c91b75a7a7e203fc7 = L.marker(
#                 [25.068914, 121.662748],
#                 {}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var icon_c2138506d93eecfcf543d198af86d633 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c8284d6722b2101c91b75a7a7e203fc7.setIcon(icon_c2138506d93eecfcf543d198af86d633);
#
#
#             marker_c8284d6722b2101c91b75a7a7e203fc7.bindTooltip(
#                 `&lt;div&gt;
#                      [汐止火車站]剩 28 台
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6eb9b0bbbe0cf5b08289bf0c8584c830 = L.marker(
#                 [25.064162, 121.658301],
#                 {}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var icon_2aaea7f5ea547a4eed2da54a195614e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6eb9b0bbbe0cf5b08289bf0c8584c830.setIcon(icon_2aaea7f5ea547a4eed2da54a195614e8);
#
#
#             marker_6eb9b0bbbe0cf5b08289bf0c8584c830.bindTooltip(
#                 `&lt;div&gt;
#                      [汐止區公所]剩 32 台
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_632041ef0c53954fa5b0a0474b3d760a = L.marker(
#                 [25.07315, 121.662555],
#                 {}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var icon_91b499c65555e3d808d4285ef289e90f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_632041ef0c53954fa5b0a0474b3d760a.setIcon(icon_91b499c65555e3d808d4285ef289e90f);
#
#
#             marker_632041ef0c53954fa5b0a0474b3d760a.bindTooltip(
#                 `&lt;div&gt;
#                      [國泰綜合醫院]剩 14 台
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_413be0d0fb2b2b472fa54dfb284f5c65 = L.marker(
#                 [24.98283, 121.54362],
#                 {}
#             ).addTo(map_0fcfad9fde18f58e66524c4949e10cf4);
#
#
#             var icon_c2f2dd27c3df76448b545d3e194431d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_413be0d0fb2b2b472fa54dfb284f5c65.setIcon(icon_

# %% [markdown]
# - 下載你的成果

# %%
m.save('demo01.html')

# %%
from google.colab import files
files.download('demo01.html')

# %% [markdown]
# - 練習題: 試著使用tooltip取代popup參數

# %%
# TODO: 請在這邊填入你的程式

# %% [markdown]
# # Demo W02-1 : 初步感受Python的威力

# %% [markdown]
# ## 快速使用套件，完成一個地圖應用

# %%
import pandas as pd

# %%
#url = "https://odws.hccg.gov.tw/001/Upload/25/opendataback/9059/59/05c978ab-e430-43cd-87a1-8e4e867c9fae.csv"
url = 'https://raw.githubusercontent.com/maloyang/csu_202309_iot/main/W01/bike_data.csv'
df = pd.read_csv(url, encoding='big5')

# %%
df.head()
# Out:
#            站點名稱        緯度         經度  \
# 0  北新竹火車站(新竹高工)  24.80963  120.98351
# 1     明志書院立體停車場  24.80167  120.96576
# 2    十八尖山(新竹高商)  24.79703  120.98755
# 3     清華大學(小吃部)  24.79307  120.99335
# 4   陽明交通大學(大學路)  24.78940  121.00026
#
#                                                   圖片                站點位置
# 0  https://odws.hccg.gov.tw/001/Upload/25/relpic/...       中華路二段2-1號前人行道
# 1  https://odws.hccg.gov.tw/001/Upload/25/relpic/...    西大路317號(停車場前人行道)
# 2  https://odws.hccg.gov.tw/001/Upload/25/relpic/...        博愛街5巷2號對面停車場
# 3  https://odws.hccg.gov.tw/001/Upload/25/relpic/...  光復路二段101號(小吃部左側廣場)
# 4  https://odws.hccg.gov.tw/001/Upload/25/relpic/...      大學路200號(對面人行道)

# %% [markdown]
# - 使用folium地圖套件進行資料視覺化應用
# - 使用geopy取得GPS資料
#
# - 安裝方式:
# ```bash
# pip install folium
# pip install geopy
# ```

# %%
# 在colab用底下的安裝指令
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)

# %%
#引入相關套件，並建立取得GPS座標的function
import folium
import geopy
from geopy.geocoders import Nominatim

def get_gps_coordinates(location_name):
    """
    取得指定地名的 GPS 座標。

    Args:
        location_name (str): 地名。

    Returns:
        tuple: (緯度, 經度)，如果找不到則返回 None。
    """
    try:
        geolocator = Nominatim(user_agent="my_geocoder")
        location = geolocator.geocode(location_name)
        if location:
            return location.latitude, location.longitude
        else:
            return None
    except Exception as e:
        print(f"發生錯誤：{e}")
        return None

# %%
location = get_gps_coordinates('新竹市')
print(location)
# Out:
# (24.8066333, 120.9686833)

# %%
m = folium.Map(location=location, zoom_start=16)

# %%
for i, row in df.iterrows():
    try:
        folium.Marker([float(row['緯度']), float(row['經度'])], popup=row['站點名稱']).add_to(m)
    except Exception as e:
        print(e.args)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_451a3fdd5f581e64555e4b8431b5e6fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_451a3fdd5f581e64555e4b8431b5e6fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_451a3fdd5f581e64555e4b8431b5e6fd = L.map(
#                 &quot;map_451a3fdd5f581e64555e4b8431b5e6fd&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0f86782cf0c801778a190e81ad02ee0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0f86782cf0c801778a190e81ad02ee0.addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#             var marker_5c2f16fdb10635fbd6dae3a7fddf3160 = L.marker(
#                 [24.80963, 120.98351],
#                 {
# }
#             ).addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#         var popup_a4a504db576e89f7b57bf1a91e8b63d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afcab550cdefa1515862ee10181200c6 = $(`&lt;div id=&quot;html_afcab550cdefa1515862ee10181200c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;北新竹火車站(新竹高工)&lt;/div&gt;`)[0];
#                 popup_a4a504db576e89f7b57bf1a91e8b63d3.setContent(html_afcab550cdefa1515862ee10181200c6);
#
#
#
#         marker_5c2f16fdb10635fbd6dae3a7fddf3160.bindPopup(popup_a4a504db576e89f7b57bf1a91e8b63d3)
#         ;
#
#
#
#
#             var marker_de02d7c694cd039b51426b8453e5b354 = L.marker(
#                 [24.80167, 120.96576],
#                 {
# }
#             ).addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#         var popup_8b4b144c509954e2043dc43a8bee1bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec0463d37bc4489cc8a914069e8d0b2 = $(`&lt;div id=&quot;html_1ec0463d37bc4489cc8a914069e8d0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;明志書院立體停車場&lt;/div&gt;`)[0];
#                 popup_8b4b144c509954e2043dc43a8bee1bc2.setContent(html_1ec0463d37bc4489cc8a914069e8d0b2);
#
#
#
#         marker_de02d7c694cd039b51426b8453e5b354.bindPopup(popup_8b4b144c509954e2043dc43a8bee1bc2)
#         ;
#
#
#
#
#             var marker_9b22cefe8b6378301555643653a37dac = L.marker(
#                 [24.79703, 120.98755],
#                 {
# }
#             ).addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#         var popup_8250bbdaf88ef7b50343ed494f60ab9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d985e8bfde0eecf2001405f295156f92 = $(`&lt;div id=&quot;html_d985e8bfde0eecf2001405f295156f92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;十八尖山(新竹高商)&lt;/div&gt;`)[0];
#                 popup_8250bbdaf88ef7b50343ed494f60ab9e.setContent(html_d985e8bfde0eecf2001405f295156f92);
#
#
#
#         marker_9b22cefe8b6378301555643653a37dac.bindPopup(popup_8250bbdaf88ef7b50343ed494f60ab9e)
#         ;
#
#
#
#
#             var marker_ebf4d4514268f1fba184f596cf213684 = L.marker(
#                 [24.79307, 120.99335],
#                 {
# }
#             ).addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#         var popup_c85235190855a3f7132bd1d6e1378608 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e1c8d6932e6d75caecb7d063cd3d07e = $(`&lt;div id=&quot;html_6e1c8d6932e6d75caecb7d063cd3d07e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清華大學(小吃部)&lt;/div&gt;`)[0];
#                 popup_c85235190855a3f7132bd1d6e1378608.setContent(html_6e1c8d6932e6d75caecb7d063cd3d07e);
#
#
#
#         marker_ebf4d4514268f1fba184f596cf213684.bindPopup(popup_c85235190855a3f7132bd1d6e1378608)
#         ;
#
#
#
#
#             var marker_4a0d784bc44cc5900108b6483f8e306d = L.marker(
#                 [24.7894, 121.00026],
#                 {
# }
#             ).addTo(map_451a3fdd5f581e64555e4b8431b5e6fd);
#
#
#         var popup_064bb35088b6189bc5ec4691ac00ff67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a951b4cb05a2d31b887b93c0d07b7d28 = $(`&lt;div id=&quot;html_a951b4cb05a2d31b887b93c0d07b7d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;陽明交通大學(大學路)&lt;/div&gt;`)[0];
#                 popup_064bb35088b6189bc5ec4691ac00ff67.setContent(html_a951b4cb05a2d31b887b93c0d07b7d28);
#
#
#
#         marker_4a0d784bc44cc5900108b6483f8e306d.bindPopup(popup_064bb35088b6189bc5ec4691ac00ff67)
#         ;
#
#
#
#
#             var marker_7697afc968bc52b74145ffd97c22b160 = L.marker(
#                 [24.78473, 120.99994],
#                 {
# }
#             )
